# %%
import re

detector_config = "epic_craterlake"
detector_version = "26.02.0"
jug_xl_tag = "26.02.0-stable"
copy_reco = "true"
copy_full = "false"
copy_log = "true"

# %%
new_demp_list = ["EXCLUSIVE/DEMP/DEMPgen-1.2.4_10x130_pi+.csv","EXCLUSIVE/DEMP/DEMPgen-1.2.4_10x250_pi+.csv"]
submitted = True

for demp in new_demp_list:
  match = re.search(r'(\d+)x(\d+)', demp)
  ebeam = match.group(1)
  pbeam = match.group(2)
  if not submitted:
    print("EBEAM="+ebeam+" PBEAM="+pbeam+" DETECTOR_VERSION="+detector_version+" DETECTOR_CONFIG="+detector_config+" JUG_XL_TAG="+jug_xl_tag+" COPYRECO="+copy_reco+" COPYFULL="+copy_full+" COPYLOG="+copy_log+" USERUCIO=true X509_USER_PROXY=secrets/x509_user_proxy scripts/submit_csv.sh osg_csv hepmc3 "+demp+" 2")

# %%
dvmp_jpsi_abconv_list = [
    "EXCLUSIVE/DVMP/lAger3.6.1-1.0_DVMP_JPsi_MuMu_10x130.csv",
    "EXCLUSIVE/DVMP/lAger3.6.1-1.0_DVMP_JPsi_MuMu_10x250.csv",
    "EXCLUSIVE/DVMP/lAger3.6.1-1.0_DVMP_JPsi_MuMu_18x275.csv"
]
submitted = True # Set to False to actually print the commands

for dvmp_jpsi_abconv in dvmp_jpsi_abconv_list:
  match = re.search(r'(\d+)x(\d+)', dvmp_jpsi_abconv)
  ebeam = match.group(1)
  pbeam = match.group(2)
  if not submitted:
    print("EBEAM="+ebeam+" PBEAM="+pbeam+" DETECTOR_VERSION="+detector_version+" DETECTOR_CONFIG="+detector_config+" JUG_XL_TAG="+jug_xl_tag+" COPYRECO="+copy_reco+" COPYFULL="+copy_full+" COPYLOG="+copy_log+" USERUCIO=true X509_USER_PROXY=secrets/x509_user_proxy scripts/submit_csv.sh osg_csv hepmc3 "+dvmp_jpsi_abconv+" 2")

# %%
dvmp_pi0_list = [
    "EXCLUSIVE/DVMP/unpolarised/EpIC1.1.6-1.0_DVMP_pi0_10x130_ab.csv",
    "EXCLUSIVE/DVMP/unpolarised/EpIC1.1.6-1.1_DVMP_pi0_18x275_ab.csv",
    "EXCLUSIVE/DVMP/unpolarised/EpIC1.1.6-1.1_DVMP_pi0_5x41_ab.csv"
]
submitted = True

for dvmp_pi0 in dvmp_pi0_list:
  match = re.search(r'(\d+)x(\d+)', dvmp_pi0)
  ebeam = match.group(1)
  pbeam = match.group(2)
  if not submitted:
    print("EBEAM="+ebeam+" PBEAM="+pbeam+" DETECTOR_VERSION="+detector_version+" DETECTOR_CONFIG="+detector_config+" JUG_XL_TAG="+jug_xl_tag+" COPYRECO="+copy_reco+" COPYFULL="+copy_full+" COPYLOG="+copy_log+" USERUCIO=true X509_USER_PROXY=secrets/x509_user_proxy scripts/submit_csv.sh osg_csv hepmc3 "+dvmp_pi0+" 2")

# %%
ddvcs_list = [
    "EXCLUSIVE/DDVCS/EpIC1.1.6-1.0_DDVCS_18x275_q2_0_10_edecay.csv",
    "EXCLUSIVE/DDVCS/EpIC1.1.6-1.0_DDVCS_18x275_q2_0_10_mudecay.csv"
]
submitted = True

for ddvcs in ddvcs_list:
  match = re.search(r'(\d+)x(\d+)', ddvcs)
  ebeam = match.group(1)
  pbeam = match.group(2)
  if not submitted:
    print("EBEAM="+ebeam+" PBEAM="+pbeam+" DETECTOR_VERSION="+detector_version+" DETECTOR_CONFIG="+detector_config+" JUG_XL_TAG="+jug_xl_tag+" COPYRECO="+copy_reco+" COPYFULL="+copy_full+" COPYLOG="+copy_log+" USERUCIO=true X509_USER_PROXY=secrets/x509_user_proxy scripts/submit_csv.sh osg_csv hepmc3 "+ddvcs+" 2")

# %%
photoproduction_jpsi_list = [
    "EXCLUSIVE/PHOTOPRODUCTION_JPSI/eSTARlight/eSTARlight1.3.0-1.0_coherent_ep_JPsi_18x275_q2_nocut_edecay.csv",
    "EXCLUSIVE/PHOTOPRODUCTION_JPSI/eSTARlight/eSTARlight1.3.0-1.0_coherent_ep_JPsi_18x275_q2_nocut_mudecay.csv"
]
submitted = True

for jpsi_file in photoproduction_jpsi_list:
  match = re.search(r'(\d+)x(\d+)', jpsi_file)
  ebeam = match.group(1)
  pbeam = match.group(2)
  if not submitted:
    print("EBEAM="+ebeam+" PBEAM="+pbeam+" DETECTOR_VERSION="+detector_version+" DETECTOR_CONFIG="+detector_config+" JUG_XL_TAG="+jug_xl_tag+" COPYRECO="+copy_reco+" COPYFULL="+copy_full+" COPYLOG="+copy_log+" USERUCIO=true X509_USER_PROXY=secrets/x509_user_proxy scripts/submit_csv.sh osg_csv hepmc3 "+jpsi_file+" 2")

# %%
diffractive_phi_list = ["EXCLUSIVE/DIFFRACTIVE_PHI/BeAGLE1.03.02-1.1_phi_eAu_10x100_q2_1to10000_hiAcc.csv"]
submitted = True

for diffractive_phi in diffractive_phi_list:
  ebeam = "10"
  pbeam = "100_Au197"
  if not submitted:
    print("EBEAM="+ebeam+" PBEAM="+pbeam+" DETECTOR_VERSION="+detector_version+" DETECTOR_CONFIG="+detector_config+" JUG_XL_TAG="+jug_xl_tag+" COPYRECO="+copy_reco+" COPYFULL="+copy_full+" COPYLOG="+copy_log+" USERUCIO=true X509_USER_PROXY=secrets/x509_user_proxy scripts/submit_csv.sh osg_csv hepmc3 "+diffractive_phi+" 2")

# %%
import re

diffractive_rho_list = ["EXCLUSIVE/DIFFRACTIVE_RHO/sartre1.39-1.1_coherent_rho_eAu_bsat_10x100_hiAcc.csv"]
submitted = True

for diffractive_rho in diffractive_rho_list:
  match = re.search(r'(\d+)x(\d+)', diffractive_rho)
  ebeam = match.group(1)
  pbeam = "100_Au197"
  if not submitted:
    print("EBEAM="+ebeam+" PBEAM="+pbeam+" DETECTOR_VERSION="+detector_version+" DETECTOR_CONFIG="+detector_config+" JUG_XL_TAG="+jug_xl_tag+" COPYRECO="+copy_reco+" COPYFULL="+copy_full+" COPYLOG="+copy_log+" USERUCIO=true X509_USER_PROXY=secrets/x509_user_proxy scripts/submit_csv.sh osg_csv hepmc3 "+diffractive_rho+" 2")

# %%
upsilon_list = [
    "EXCLUSIVE/UPSILON/UPSILON_18x275_hiAcc.csv",
    "EXCLUSIVE/UPSILON/UPSILON_18x275_hiDiv.csv"
]
submitted = True

for upsilon_file in upsilon_list:
  match = re.search(r'(\d+)x(\d+)', upsilon_file)
  ebeam = match.group(1)
  pbeam = match.group(2)
  if not submitted:
    print("EBEAM="+ebeam+" PBEAM="+pbeam+" DETECTOR_VERSION="+detector_version+" DETECTOR_CONFIG="+detector_config+" JUG_XL_TAG="+jug_xl_tag+" COPYRECO="+copy_reco+" COPYFULL="+copy_full+" COPYLOG="+copy_log+" USERUCIO=true X509_USER_PROXY=secrets/x509_user_proxy scripts/submit_csv.sh osg_csv hepmc3 "+upsilon_file+" 2")

# %%
diffractive_jpsi_list = ["EXCLUSIVE/DIFFRACTIVE_JPSI/lAger/lAger3.6.1-1.0_jpsi_10x100_hiAcc.csv","EXCLUSIVE/DIFFRACTIVE_JPSI/lAger/lAger3.6.1-1.0_jpsi_18x275_hiAcc.csv", "EXCLUSIVE/DIFFRACTIVE_JPSI/lAger/lAger3.6.1-1.0_jpsi_5x100_hiAcc.csv", "EXCLUSIVE/DIFFRACTIVE_JPSI/lAger/lAger3.6.1-1.0_jpsi_5x41_hiAcc.csv", "EXCLUSIVE/DIFFRACTIVE_JPSI/lAger/lAger3.6.1-1.0_jpsi_10x130_hiAcc.csv"]
submitted = True

for diffractive_jpsi in diffractive_jpsi_list:
  match = re.search(r'(\d+)x(\d+)', diffractive_jpsi)
  ebeam = match.group(1)
  pbeam = match.group(2)
  if not submitted:
    print("EBEAM="+ebeam+" PBEAM="+pbeam+" DETECTOR_VERSION="+detector_version+" DETECTOR_CONFIG="+detector_config+" JUG_XL_TAG="+jug_xl_tag+" COPYRECO="+copy_reco+" COPYFULL="+copy_full+" COPYLOG="+copy_log+" USERUCIO=true X509_USER_PROXY=secrets/x509_user_proxy scripts/submit_csv.sh osg_csv hepmc3 "+diffractive_jpsi+" 2")

# %%
detector_config="epic_craterlake_without_zdc"
eA_list = ["DIS/eA/BeAGLE1.03.02-2.0_DIS_eAu_10x100_q2_1to10.csv","DIS/eA/BeAGLE1.03.02-2.0_DIS_eAu_10x100_q2_10to100.csv","DIS/eA/BeAGLE1.03.02-2.0_DIS_eAu_5x41_q2_1to10.csv","DIS/eA/BeAGLE1.03.02-2.0_DIS_eAu_5x41_q2_10to100.csv"]
pbeam_list=["100_Au197", "100_Au197","41_Au197", "41_Au197"]
submitted = True

for eA, pbeam in zip(eA_list, pbeam_list):
  match = re.search(r'(\d+)x(\d+)', eA)
  ebeam = match.group(1)
  if not submitted:
    print("EBEAM="+ebeam+" PBEAM="+pbeam+" DETECTOR_VERSION="+detector_version+" DETECTOR_CONFIG="+detector_config+" JUG_XL_TAG="+jug_xl_tag+" COPYRECO="+copy_reco+" COPYFULL="+copy_full+" COPYLOG="+copy_log+" USERUCIO=true X509_USER_PROXY=secrets/x509_user_proxy scripts/submit_csv.sh osg_csv hepmc3 "+eA+" 2")

detector_config="epic_craterlake"

# %%
sidis_pythia_list = [
    "SIDIS/pythia8.306-1.0_D0_18x275_hiDiv.csv",
    "SIDIS/pythia8.306-1.1_D0_10x100_hiDiv.csv",
]
submitted = True

for sidis_file in sidis_pythia_list:
  match = re.search(r'(\d+)x(\d+)', sidis_file)
  ebeam = match.group(1)
  pbeam = match.group(2)
  if not submitted:
    print("EBEAM="+ebeam+" PBEAM="+pbeam+" DETECTOR_VERSION="+detector_version+" DETECTOR_CONFIG="+detector_config+" JUG_XL_TAG="+jug_xl_tag+" COPYRECO="+copy_reco+" COPYFULL="+copy_full+" COPYLOG="+copy_log+" USERUCIO=true X509_USER_PROXY=secrets/x509_user_proxy scripts/submit_csv.sh osg_csv hepmc3 "+sidis_file+" 2")

# %%
import re

ddis_list = [
    "DDIS/rapgap3.310-1.0_ddis_ep_noRad_10x100.csv"
]
submitted = True # Set to False to actually print the commands

for ddis_file in ddis_list:
  match = re.search(r'(\d+)x(\d+)', ddis_file)
  ebeam = match.group(1)
  pbeam = match.group(2)
  if not submitted:
    print("EBEAM="+ebeam+" PBEAM="+pbeam+" DETECTOR_VERSION="+detector_version+" DETECTOR_CONFIG="+detector_config+" JUG_XL_TAG="+jug_xl_tag+" COPYRECO="+copy_reco+" COPYFULL="+copy_full+" COPYLOG="+copy_log+" USERUCIO=true X509_USER_PROXY=secrets/x509_user_proxy scripts/submit_csv.sh osg_csv hepmc3 "+ddis_file+" 2")

# %%
import re

dvcs_BH_abconv_list = [
    "EXCLUSIVE/DVCS/EpIC_v1.1.6-1.2_DVCS_BH_10x100_q2_1_100_abconv.csv",
    "EXCLUSIVE/DVCS/EpIC_v1.1.6-1.2_DVCS_BH_10x130_q2_1_100_abconv.csv",
    "EXCLUSIVE/DVCS/EpIC_v1.1.6-1.2_DVCS_BH_10x250_q2_1_100_abconv.csv",
    "EXCLUSIVE/DVCS/EpIC_v1.1.6-1.2_DVCS_BH_18x275_q2_1_100_abconv.csv",
    "EXCLUSIVE/DVCS/EpIC_v1.1.6-1.2_DVCS_BH_5x41_q2_1_100_abconv.csv"
]
submitted = True # Set to False to actually print the commands

for dvcs in dvcs_BH_abconv_list:
  match = re.search(r'(\d+)x(\d+)', dvcs)
  ebeam = match.group(1)
  pbeam = match.group(2)
  if not submitted:
    print("EBEAM="+ebeam+" PBEAM="+pbeam+" DETECTOR_VERSION="+detector_version+" DETECTOR_CONFIG="+detector_config+" JUG_XL_TAG="+jug_xl_tag+" COPYRECO="+copy_reco+" COPYFULL="+copy_full+" COPYLOG="+copy_log+" USERUCIO=true X509_USER_PROXY=secrets/x509_user_proxy scripts/submit_csv.sh osg_csv hepmc3 "+dvcs+" 2")

# %%
eA_list = ["DIS/eA/BeAGLE1.03.02-1.2_DIS_eHe3_10x110_q2_2to10.csv", "DIS/eA/BeAGLE1.03.02-1.2_DIS_eHe3_10x110_q2_10to100.csv", "DIS/eA/BeAGLE1.03.02-1.2_DIS_eHe3_10x110_q2_100to10000.csv", "DIS/eA/BeAGLE1.03.02-1.2_DIS_eHe3_18x110_q2_2to10.csv", "DIS/eA/BeAGLE1.03.02-1.2_DIS_eHe3_18x110_q2_10to100.csv", "DIS/eA/BeAGLE1.03.02-1.2_DIS_eHe3_18x110_q2_100to10000.csv", "DIS/eA/BeAGLE1.03.02-1.2_DIS_eHe3_5x41_q2_2to10.csv", "DIS/eA/BeAGLE1.03.02-1.2_DIS_eHe3_5x41_q2_10to100.csv", "DIS/eA/BeAGLE1.03.02-1.2_DIS_eHe3_5x41_q2_100to10000.csv", ]
pbeam_list=["110_He3", "110_He3", "110_He3", "110_He3", "110_He3", "110_He3", "41_He3", "41_He3", "41_He3"]
submitted = True

for eA, pbeam in zip(eA_list, pbeam_list):
  match = re.search(r'(\d+)x(\d+)', eA)
  ebeam = match.group(1)
  if not submitted:
    print("EBEAM="+ebeam+" PBEAM="+pbeam+" DETECTOR_VERSION="+detector_version+" DETECTOR_CONFIG="+detector_config+" JUG_XL_TAG="+jug_xl_tag+" COPYRECO="+copy_reco+" COPYFULL="+copy_full+" COPYLOG="+copy_log+" USERUCIO=true X509_USER_PROXY=secrets/x509_user_proxy scripts/submit_csv.sh osg_csv hepmc3 "+eA+" 2")

# %%
eA_list = [
    "DIS/eA/BeAGLE1.03.02-2.1_DIS_eHe3_10x166_q2_2to10.csv",
    "DIS/eA/BeAGLE1.03.02-2.1_DIS_eHe3_10x166_q2_10to100.csv",
    "DIS/eA/BeAGLE1.03.02-2.1_DIS_eHe3_10x166_q2_100to10000.csv"
]
pbeam_list=["166_He3", "166_He3", "166_He3"]
submitted = True

for eA, pbeam in zip(eA_list, pbeam_list):
  match = re.search(r'(\d+)x(\d+)', eA)
  ebeam = match.group(1)
  if not submitted:
    print("EBEAM="+ebeam+" PBEAM="+pbeam+" DETECTOR_VERSION="+detector_version+" DETECTOR_CONFIG="+detector_config+" JUG_XL_TAG="+jug_xl_tag+" COPYRECO="+copy_reco+" COPYFULL="+copy_full+" COPYLOG="+copy_log+" USERUCIO=true X509_USER_PROXY=secrets/x509_user_proxy scripts/submit_csv.sh osg_csv hepmc3 "+eA+" 2")

# %%
sidis_dijet_list = [
    "SIDIS/DIJET/pythia6.428-dijet-v1.0_PGF_noRC_ep_18x275_q2_1to20000_ab.csv"
]
submitted = True

for sidis_dijet in sidis_dijet_list:
  match = re.search(r'(\d+)x(\d+)', sidis_dijet)
  ebeam = match.group(1)
  pbeam = match.group(2)
  if not submitted:
    print("EBEAM="+ebeam+" PBEAM="+pbeam+" DETECTOR_VERSION="+detector_version+" DETECTOR_CONFIG="+detector_config+" JUG_XL_TAG="+jug_xl_tag+" COPYRECO="+copy_reco+" COPYFULL="+copy_full+" COPYLOG="+copy_log+" USERUCIO=true X509_USER_PROXY=secrets/x509_user_proxy scripts/submit_csv.sh osg_csv hepmc3 "+sidis_dijet+" 2")

# %%
eA_list = ["SIDIS/ep/pythia8.306-1.2_D0_ep_5x41_q2_1to10000.csv","SIDIS/ep/pythia8.306-1.2_Lc_ep_10x100_q2_1to10000.csv"]
pbeam_list=["41", "100"]
submitted = True

for eA, pbeam in zip(eA_list, pbeam_list):
  match = re.search(r'(\d+)x(\d+)', eA)
  ebeam = match.group(1)
  if not submitted:
    print("EBEAM="+ebeam+" PBEAM="+pbeam+" DETECTOR_VERSION="+detector_version+" DETECTOR_CONFIG="+detector_config+" JUG_XL_TAG="+jug_xl_tag+" COPYRECO="+copy_reco+" COPYFULL="+copy_full+" COPYLOG="+copy_log+" USERUCIO=true X509_USER_PROXY=secrets/x509_user_proxy scripts/submit_csv.sh osg_csv hepmc3 "+eA+" 2")

# %%
import re

meson_sf_list = [
    "EXCLUSIVE/MESON_SF/eicMesonSFGen-1.0.0_K+Lambda_ep_10x100_ab.csv",
    "EXCLUSIVE/MESON_SF/eicMesonSFGen-1.0.0_K+Lambda_ep_10x130_ab.csv",
    "EXCLUSIVE/MESON_SF/eicMesonSFGen-1.0.0_K+Lambda_ep_18x275_ab.csv",
    "EXCLUSIVE/MESON_SF/eicMesonSFGen-1.0.0_K+Lambda_ep_5x41_ab.csv"
]
submitted = False

for meson_sf in meson_sf_list:
  match = re.search(r'(\d+)x(\d+)', meson_sf)
  ebeam = match.group(1)
  pbeam = match.group(2)
  if not submitted:
    print("EBEAM="+ebeam+" PBEAM="+pbeam+" DETECTOR_VERSION="+detector_version+" DETECTOR_CONFIG="+detector_config+" JUG_XL_TAG="+jug_xl_tag+" COPYRECO="+copy_reco+" COPYFULL="+copy_full+" COPYLOG="+copy_log+" USERUCIO=true X509_USER_PROXY=secrets/x509_user_proxy scripts/submit_csv.sh osg_csv hepmc3 "+meson_sf+" 2")
# Out:
# EBEAM=10 PBEAM=100 DETECTOR_VERSION=26.02.0 DETECTOR_CONFIG=epic_craterlake JUG_XL_TAG=26.02.0-stable COPYRECO=true COPYFULL=false COPYLOG=true USERUCIO=true X509_USER_PROXY=secrets/x509_user_proxy scripts/submit_csv.sh osg_csv hepmc3 EXCLUSIVE/MESON_SF/eicMesonSFGen-1.0.0_K+Lambda_ep_10x100_ab.csv 2
# EBEAM=10 PBEAM=130 DETECTOR_VERSION=26.02.0 DETECTOR_CONFIG=epic_craterlake JUG_XL_TAG=26.02.0-stable COPYRECO=true COPYFULL=false COPYLOG=true USERUCIO=true X509_USER_PROXY=secrets/x509_user_proxy scripts/submit_csv.sh osg_csv hepmc3 EXCLUSIVE/MESON_SF/eicMesonSFGen-1.0.0_K+Lambda_ep_10x130_ab.csv 2
# EBEAM=18 PBEAM=275 DETECTOR_VERSION=26.02.0 DETECTOR_CONFIG=epic_craterlake JUG_XL_TAG=26.02.0-stable COPYRECO=true COPYFULL=false COPYLOG=true USERUCIO=true X509_USER_PROXY=secrets/x509_user_proxy scripts/submit_csv.sh osg_csv hepmc3 EXCLUSIVE/MESON_SF/eicMesonSFGen-1.0.0_K+Lambda_ep_18x275_ab.csv 2
# ...

# %%
diffractive_phi_list = ["EXCLUSIVE/DIFFRACTIVE_PHI/Sartre_Coherent.csv","EXCLUSIVE/DIFFRACTIVE_PHI/Sartre_Coherent_q2_15.csv"]
submitted = False

for diffractive_phi in diffractive_phi_list:
  ebeam = "18"
  pbeam = "110_Au"
  if not submitted:
    print("EBEAM="+ebeam+" PBEAM="+pbeam+" DETECTOR_VERSION="+detector_version+" DETECTOR_CONFIG="+detector_config+" JUG_XL_TAG="+jug_xl_tag+" COPYRECO="+copy_reco+" COPYFULL="+copy_full+" COPYLOG="+copy_log+" USERUCIO=true X509_USER_PROXY=secrets/x509_user_proxy scripts/submit_csv.sh osg_csv hepmc3 "+diffractive_phi+" 2")

# %%
uchannel_list = ["EXCLUSIVE/UCHANNEL_PI0/18x275/Q2=0to10/pi0_18x275_uChannel_Q2of0to10_hiDiv.csv", "EXCLUSIVE/UCHANNEL_RHO/10x100/Q2=0to10/rho_10x100_uChannel_Q2of0to10_hiDiv.csv"]
submitted = False

for uchannel in uchannel_list:
  match = re.search(r'(\d+)x(\d+)', uchannel)
  ebeam = match.group(1)
  pbeam = match.group(2)
  if not submitted:
    print("EBEAM="+ebeam+" PBEAM="+pbeam+" DETECTOR_VERSION="+detector_version+" DETECTOR_CONFIG="+detector_config+" JUG_XL_TAG="+jug_xl_tag+" COPYRECO="+copy_reco+" COPYFULL="+copy_full+" COPYLOG="+copy_log+" USERUCIO=true X509_USER_PROXY=secrets/x509_user_proxy scripts/submit_csv.sh osg_csv hepmc3 "+uchannel+" 2")

# %%
dvcs_NEW_list = ["EXCLUSIVE/DVCS/EpIC_v1.1.6-1.1_DVCS_BH_INT_10x130_hiAcc.csv"]
submitted = False

for dvcs in dvcs_NEW_list:
  match = re.search(r'(\d+)x(\d+)', dvcs)
  ebeam = match.group(1)
  pbeam = match.group(2)
  if not submitted:
    print("EBEAM="+ebeam+" PBEAM="+pbeam+" DETECTOR_VERSION="+detector_version+" DETECTOR_CONFIG="+detector_config+" JUG_XL_TAG="+jug_xl_tag+" COPYRECO="+copy_reco+" COPYFULL="+copy_full+" COPYLOG="+copy_log+" USERUCIO=true X509_USER_PROXY=secrets/x509_user_proxy scripts/submit_csv.sh osg_csv hepmc3 "+dvcs+" 2")

# %%
diffractive_jpsi_STARLIGHT_list = ["EXCLUSIVE/DIFFRACTIVE_JPSI/eSTARlight/eSTARlight1.2.0-1.0_coherent_eCu_jpsi_10x115_afterburned.csv","EXCLUSIVE/DIFFRACTIVE_JPSI/eSTARlight/eSTARlight1.2.0-1.0_coherent_eRu_jpsi_10x115_afterburned.csv"]
pbeam_list=["115_Cu63","115_Ru96"]
submitted = False

for diffractive_jpsi, pbeam in zip(diffractive_jpsi_STARLIGHT_list, pbeam_list):
  match = re.search(r'(\d+)x(\d+)', diffractive_jpsi)
  ebeam = match.group(1)
  if not submitted:
    print("EBEAM="+ebeam+" PBEAM="+pbeam+" DETECTOR_VERSION="+detector_version+" DETECTOR_CONFIG="+detector_config+" JUG_XL_TAG="+jug_xl_tag+" COPYRECO="+copy_reco+" COPYFULL="+copy_full+" COPYLOG="+copy_log+" USERUCIO=true X509_USER_PROXY=secrets/x509_user_proxy scripts/submit_csv.sh osg_csv hepmc3 "+diffractive_jpsi+" 2")

# %%
diffractive_phi_STARLIGHT_list = ["EXCLUSIVE/DIFFRACTIVE_PHI/eSTARlight/eSTARlight1.2.0-1.0_coherent_eCu_phi_10x115_afterburned.csv","EXCLUSIVE/DIFFRACTIVE_PHI/eSTARlight/eSTARlight1.2.0-1.0_coherent_eRu_phi_10x115_afterburned.csv"]
pbeam_list=["115_Cu63","115_Ru96"]
submitted = False

for diffractive_phi, pbeam in zip(diffractive_phi_STARLIGHT_list, pbeam_list):
  match = re.search(r'(\d+)x(\d+)', diffractive_phi)
  ebeam = match.group(1)
  if not submitted:
    print("EBEAM="+ebeam+" PBEAM="+pbeam+" DETECTOR_VERSION="+detector_version+" DETECTOR_CONFIG="+detector_config+" JUG_XL_TAG="+jug_xl_tag+" COPYRECO="+copy_reco+" COPYFULL="+copy_full+" COPYLOG="+copy_log+" USERUCIO=true X509_USER_PROXY=secrets/x509_user_proxy scripts/submit_csv.sh osg_csv hepmc3 "+diffractive_phi+" 2")

# %%
eA_list = ["DIS/eA/BeAGLE1.03.02-1.0_DIS_eCu_en_10x115.csv","DIS/eA/BeAGLE1.03.02-1.0_DIS_eCu_ep_10x115.csv","DIS/eA/BeAGLE1.03.02-1.0_DIS_eRu_en_10x115.csv","DIS/eA/BeAGLE1.03.02-1.0_DIS_eRu_ep_10x115.csv", "DIS/eA/BeAGLE1.03.02-1.0_DIS_eHe3_10x166.csv"]
pbeam_list=["115_Cu63", "115_Cu63","115_Ru96", "115_Ru96"]
submitted = False

for eA, pbeam in zip(eA_list, pbeam_list):
  match = re.search(r'(\d+)x(\d+)', eA)
  ebeam = match.group(1)
  if not submitted:
    print("EBEAM="+ebeam+" PBEAM="+pbeam+" DETECTOR_VERSION="+detector_version+" DETECTOR_CONFIG="+detector_config+" JUG_XL_TAG="+jug_xl_tag+" COPYRECO="+copy_reco+" COPYFULL="+copy_full+" COPYLOG="+copy_log+" USERUCIO=true X509_USER_PROXY=secrets/x509_user_proxy scripts/submit_csv.sh osg_csv hepmc3 "+eA+" 2")

# %%
detector_config="epic_craterlake_without_zdc"
eA_list = ["SIDIS/eA/BeAGLE1.03.01-2.0_D0_eAu_10x100_q2_1to10000.csv","SIDIS/eA/BeAGLE1.03.01-2.0_D0_eAu_5x41_q2_1to10000.csv","SIDIS/eA/BeAGLE1.03.01-2.0_Lc_eAu_10x100_q2_1to10000.csv"]
pbeam_list=["100_Au197","41_Au197", "100_Au197"]
submitted = False

for eA, pbeam in zip(eA_list, pbeam_list):
  match = re.search(r'(\d+)x(\d+)', eA)
  ebeam = match.group(1)
  if not submitted:
    print("EBEAM="+ebeam+" PBEAM="+pbeam+" DETECTOR_VERSION="+detector_version+" DETECTOR_CONFIG="+detector_config+" JUG_XL_TAG="+jug_xl_tag+" COPYRECO="+copy_reco+" COPYFULL="+copy_full+" COPYLOG="+copy_log+" USERUCIO=true X509_USER_PROXY=secrets/x509_user_proxy scripts/submit_csv.sh osg_csv hepmc3 "+eA+" 2")

detector_config="epic_craterlake"

# %%
import re

dis_nc_list = [
    "DIS/NC/10x130/pythia6.428-1.0_NC_noRad_ep_10x130_q2_10to100.csv",
    "DIS/NC/10x130/pythia6.428-1.0_NC_noRad_ep_10x130_q2_1000to10000.csv",
    "DIS/NC/10x130/pythia6.428-1.0_NC_noRad_ep_10x130_q2_1to10.csv",
    "DIS/NC/10x130/pythia6.428-1.0_NC_noRad_ep_10x130_q2_100to1000.csv",
    "DIS/NC/10x250/pythia6.428-1.0_NC_noRad_ep_10x250_q2_10to100.csv",
    "DIS/NC/10x250/pythia6.428-1.0_NC_noRad_ep_10x250_q2_1000to10000.csv",
    "DIS/NC/10x250/pythia6.428-1.0_NC_noRad_ep_10x250_q2_1to10.csv",
    "DIS/NC/10x250/pythia6.428-1.0_NC_noRad_ep_10x250_q2_100to1000.csv"
]
submitted = False

for dis_nc_file in dis_nc_list:
  match = re.search(r'(\d+)x(\d+)', dis_nc_file)
  ebeam = match.group(1)
  pbeam = match.group(2)
  if not submitted:
    print("EBEAM="+ebeam+" PBEAM="+pbeam+" DETECTOR_VERSION="+detector_version+" DETECTOR_CONFIG="+detector_config+" JUG_XL_TAG="+jug_xl_tag+" COPYRECO="+copy_reco+" COPYFULL="+copy_full+" COPYLOG="+copy_log+" USERUCIO=true X509_USER_PROXY=secrets/x509_user_proxy scripts/submit_csv.sh osg_csv hepmc3 "+dis_nc_file+" 2")

# %%
### Leave this to Sakib for now


submitted = True
scaling = "0.1"  # Constant for all runs

bg_csv_list = [
    "DIS_NC_10x100_minQ2=1_DefaultCoating_Bkg.csv",
    "DIS_NC_10x100_minQ2=1_GoldCoating_Bkg.csv",
    "DIS_NC_10x275_minQ2=1_DefaultCoating_Bkg.csv",
    "DIS_NC_10x275_minQ2=1_GoldCoating_Bkg.csv",
    "DIS_NC_18x275_minQ2=1_DefaultCoating_Bkg.csv",
    "DIS_NC_18x275_minQ2=1_GoldCoating_Bkg.csv"
]

for csv_file in bg_csv_list:
    # 1. Extract Beam Energies
    energy_match = re.search(r'(\d+)x(\d+)', csv_file)
    ebeam, pbeam = energy_match.groups()

    # 2. Handle Coating/Thickness Logic
    # 5um corresponds to "vacuum" in your BG_FILES, 10um corresponds to "GoldCoating_10um"
    if "Gold" in csv_file:
        thickness = "10um"
        bg_label = "GoldCoating_10um"
    else:
        thickness = "5um"
        bg_label = "vacuum"

    # 3. Construct dynamic components
    tag_prefix = f"Bkg_Exact1S_2us/GoldCt/{thickness}"

    bg_json = (
        f"synrad_egasbrems_egascoulomb_egastouschek_hgas_"
        f"{ebeam}GeVx{pbeam}GeV_{bg_label}_10000Ahr_machineruntime_50s.json"
    )

    # 4. Assemble the command
    cmd = (
        f"EBEAM={ebeam} PBEAM={pbeam} "
        f"DETECTOR_VERSION={detector_version} DETECTOR_CONFIG={detector_config} JUG_XL_TAG={jug_xl_tag} "
        f"COPYRECO=true COPYFULL=true COPYLOG=true USERUCIO=true "
        f"X509_USER_PROXY=secrets/x509_user_proxy "
        f"SIGNAL_FREQ=0 SIGNAL_STATUS=0 "
        f"TAG_PREFIX={tag_prefix} CSV_FILE={csv_file} BG_FILES={bg_json} "
        f"scripts/submit_csv.sh osg_csv hepmc3 {csv_file} {scaling}"
    )

    if not submitted:
     print(cmd)

# %%
import re

dvcs_BH_abconv_list = [
    "EXCLUSIVE/DVCS/EpIC_v1.1.6-1.2_DVCS_BH_10x100_q2_1_100_abconv.csv",
    "EXCLUSIVE/DVCS/EpIC_v1.1.6-1.2_DVCS_BH_18x275_q2_1_100_abconv.csv"
]

scaling = "0.1"  # Constant for all runs
submitted_dvcs_bg_specific = True # Set to False to actually print the commands

for dvcs_file in dvcs_BH_abconv_list:
  match = re.search(r'(\d+)x(\d+)', dvcs_file)
  ebeam = match.group(1)
  pbeam = match.group(2)

  # Define coating configurations for background
  coating_configs = [
      {"thickness": "5um", "bg_label": "vacuum"},
      {"thickness": "10um", "bg_label": "GoldCoating_10um"}
  ]

  for config in coating_configs:
    thickness = config["thickness"]
    bg_label = config["bg_label"]

    tag_prefix = f"Bkg_Exact1S_2us/GoldCt/{thickness}"

    bg_json = (
        f"synrad_egasbrems_egascoulomb_egastouschek_hgas_" +
        f"{ebeam}GeVx{pbeam}GeV_{bg_label}_10000Ahr_machineruntime_50s.json"
    )

    cmd = (
        f"EBEAM={ebeam} PBEAM={pbeam} " +
        f"DETECTOR_VERSION={detector_version} DETECTOR_CONFIG={detector_config} JUG_XL_TAG={jug_xl_tag} " +
        f"COPYRECO=true COPYFULL=false COPYLOG=true USERUCIO=true " +
        f"X509_USER_PROXY=secrets/x509_user_proxy " +
        f"SIGNAL_FREQ=0 SIGNAL_STATUS=0 " + # These are key for background-only submission
        f"TAG_PREFIX={tag_prefix} CSV_FILE={dvcs_file} BG_FILES={bg_json} " + # Use the specific DVCS file here
        f"scripts/submit_csv.sh osg_csv hepmc3 {dvcs_file} {scaling}"
    )

    if not submitted_dvcs_bg_specific:
     print(cmd)

# %%
import re

ddvcs_list = [
    "EXCLUSIVE/DDVCS/EpIC1.1.6-1.0_DDVCS_18x275_q2_0_10_edecay.csv",
    "EXCLUSIVE/DDVCS/EpIC1.1.6-1.0_DDVCS_18x275_q2_0_10_mudecay.csv"
]

scaling = "0.1"  # Constant for all runs
submitted_ddvcs_bg_specific = True # Set to False to actually print the commands

for ddvcs_file in ddvcs_list:
  match = re.search(r'(\d+)x(\d+)', ddvcs_file)
  ebeam = match.group(1)
  pbeam = match.group(2)

  # Define coating configurations for background
  coating_configs = [
      {"thickness": "5um", "bg_label": "vacuum"},
      {"thickness": "10um", "bg_label": "GoldCoating_10um"}
  ]

  for config in coating_configs:
    thickness = config["thickness"]
    bg_label = config["bg_label"]

    tag_prefix = f"Bkg_Exact1S_2us/GoldCt/{thickness}"

    bg_json = (
        f"synrad_egasbrems_egascoulomb_egastouschek_hgas_" +
        f"{ebeam}GeVx{pbeam}GeV_{bg_label}_10000Ahr_machineruntime_50s.json"
    )

    cmd = (
        f"EBEAM={ebeam} PBEAM={pbeam} " +
        f"DETECTOR_VERSION={detector_version} DETECTOR_CONFIG={detector_config} JUG_XL_TAG={jug_xl_tag} " +
        f"COPYRECO=true COPYFULL=false COPYLOG=true USERUCIO=true " +
        f"X509_USER_PROXY=secrets/x509_user_proxy " +
        f"SIGNAL_FREQ=0 SIGNAL_STATUS=0 " + # These are key for background-only submission
        f"TAG_PREFIX={tag_prefix} CSV_FILE={ddvcs_file} BG_FILES={bg_json} " + # Use the specific DDVCS file here
        f"scripts/submit_csv.sh osg_csv hepmc3 {ddvcs_file} {scaling}"
    )

    if not submitted_ddvcs_bg_specific:
     print(cmd)

# %%
import re

photoproduction_jpsi_list = [
    "EXCLUSIVE/PHOTOPRODUCTION_JPSI/eSTARlight/eSTARlight1.3.0-1.0_coherent_ep_JPsi_18x275_q2_nocut_edecay.csv",
    "EXCLUSIVE/PHOTOPRODUCTION_JPSI/eSTARlight/eSTARlight1.3.0-1.0_coherent_ep_JPsi_18x275_q2_nocut_mudecay.csv"
]

scaling = "0.1"  # Constant for all runs
submitted_jpsi_bg_specific = True # Set to False to actually print the commands

for jpsi_file in photoproduction_jpsi_list:
  match = re.search(r'(\d+)x(\d+)', jpsi_file)
  ebeam = match.group(1)
  pbeam = match.group(2)

  # Define coating configurations for background
  coating_configs = [
      {"thickness": "5um", "bg_label": "vacuum"},
      {"thickness": "10um", "bg_label": "GoldCoating_10um"}
  ]

  for config in coating_configs:
    thickness = config["thickness"]
    bg_label = config["bg_label"]

    tag_prefix = f"Bkg_Exact1S_2us/GoldCt/{thickness}"

    bg_json = (
        f"synrad_egasbrems_egascoulomb_egastouschek_hgas_" +
        f"{ebeam}GeVx{pbeam}GeV_{bg_label}_10000Ahr_machineruntime_50s.json"
    )

    cmd = (
        f"EBEAM={ebeam} PBEAM={pbeam} " +
        f"DETECTOR_VERSION={detector_version} DETECTOR_CONFIG={detector_config} JUG_XL_TAG={jug_xl_tag} " +
        f"COPYRECO=true COPYFULL=false COPYLOG=true USERUCIO=true " +
        f"X509_USER_PROXY=secrets/x509_user_proxy " +
        f"SIGNAL_FREQ=0 SIGNAL_STATUS=0 " + # These are key for background-only submission
        f"TAG_PREFIX={tag_prefix} CSV_FILE={jpsi_file} BG_FILES={bg_json} " + # Use the specific JPSI file here
        f"scripts/submit_csv.sh osg_csv hepmc3 {jpsi_file} {scaling}"
    )

    if not submitted_jpsi_bg_specific:
     print(cmd)

# %%
import re

demp_list = [
    "EXCLUSIVE/DEMP/DEMPgen-1.2.4_10x130_pi+.csv"
]

scaling = "0.1"  # Constant for all runs
submitted_demp_bg_specific = True # Set to False to actually print the commands

for demp_file in demp_list:
  match = re.search(r'(\d+)x(\d+)', demp_file)
  ebeam = match.group(1)
  pbeam = match.group(2)

  # Define coating configurations for background
  coating_configs = [
      {"thickness": "5um", "bg_label": "vacuum"},
      {"thickness": "10um", "bg_label": "GoldCoating_10um"}
  ]

  for config in coating_configs:
    thickness = config["thickness"]
    bg_label = config["bg_label"]

    tag_prefix = f"Bkg_Exact1S_2us/GoldCt/{thickness}"

    bg_json = (
        f"synrad_egasbrems_egascoulomb_egastouschek_hgas_" +
        f"{ebeam}GeVx{pbeam}GeV_{bg_label}_10000Ahr_machineruntime_50s.json"
    )

    cmd = (
        f"EBEAM={ebeam} PBEAM={pbeam} " +
        f"DETECTOR_VERSION={detector_version} DETECTOR_CONFIG={detector_config} JUG_XL_TAG={jug_xl_tag} " +
        f"COPYRECO=true COPYFULL=false COPYLOG=true USERUCIO=true " +
        f"X509_USER_PROXY=secrets/x509_user_proxy " +
        f"SIGNAL_FREQ=0 SIGNAL_STATUS=0 " + # These are key for background-only submission
        f"TAG_PREFIX={tag_prefix} CSV_FILE={demp_file} BG_FILES={bg_json} " + # Use the specific DEMP file here
        f"scripts/submit_csv.sh osg_csv hepmc3 {demp_file} {scaling}"
    )

    if not submitted_demp_bg_specific:
     print(cmd)

# %%
import re

dvmp_pi0_list = [
    "EXCLUSIVE/DVMP/unpolarised/EpIC1.1.6-1.0_DVMP_pi0_10x130_ab.csv",
    "EXCLUSIVE/DVMP/unpolarised/EpIC1.1.6-1.1_DVMP_pi0_18x275_ab.csv"
]

scaling = "0.1"  # Constant for all runs
submitted_dvmp_pi0_bg_specific = False # Set to False to actually print the commands

for dvmp_pi0_file in dvmp_pi0_list:
  match = re.search(r'(\d+)x(\d+)', dvmp_pi0_file)
  ebeam = match.group(1)
  pbeam = match.group(2)

  # Define coating configurations for background
  coating_configs = [
      {"thickness": "5um", "bg_label": "vacuum"},
      {"thickness": "10um", "bg_label": "GoldCoating_10um"}
  ]

  for config in coating_configs:
    thickness = config["thickness"]
    bg_label = config["bg_label"]

    tag_prefix = f"Bkg_Exact1S_2us/GoldCt/{thickness}"

    bg_json = (
        f"synrad_egasbrems_egascoulomb_egastouschek_hgas_" +
        f"{ebeam}GeVx{pbeam}GeV_{bg_label}_10000Ahr_machineruntime_50s.json"
    )

    cmd = (
        f"EBEAM={ebeam} PBEAM={pbeam} " +
        f"DETECTOR_VERSION={detector_version} DETECTOR_CONFIG={detector_config} JUG_XL_TAG={jug_xl_tag} " +
        f"COPYRECO=true COPYFULL=false COPYLOG=true USERUCIO=true " +
        f"X509_USER_PROXY=secrets/x509_user_proxy " +
        f"SIGNAL_FREQ=0 SIGNAL_STATUS=0 " + # These are key for background-only submission
        f"TAG_PREFIX={tag_prefix} CSV_FILE={dvmp_pi0_file} BG_FILES={bg_json} " + # Use the specific DVMP pi0 file here
        f"scripts/submit_csv.sh osg_csv hepmc3 {dvmp_pi0_file} {scaling}"
    )

    if not submitted_dvmp_pi0_bg_specific:
     print(cmd)
# Out:
# EBEAM=10 PBEAM=130 DETECTOR_VERSION=26.02.0 DETECTOR_CONFIG=epic_craterlake JUG_XL_TAG=26.02.0-stable COPYRECO=true COPYFULL=false COPYLOG=true USERUCIO=true X509_USER_PROXY=secrets/x509_user_proxy SIGNAL_FREQ=0 SIGNAL_STATUS=0 TAG_PREFIX=Bkg_Exact1S_2us/GoldCt/5um CSV_FILE=EXCLUSIVE/DVMP/unpolarised/EpIC1.1.6-1.0_DVMP_pi0_10x130_ab.csv BG_FILES=synrad_egasbrems_egascoulomb_egastouschek_hgas_10GeVx130GeV_vacuum_10000Ahr_machineruntime_50s.json scripts/submit_csv.sh osg_csv hepmc3 EXCLUSIVE/DVMP/unpolarised/EpIC1.1.6-1.0_DVMP_pi0_10x130_ab.csv 0.1
# ...

# %%
import re

dis_nc_minQ2_list = [
    "DIS/NC/10x100/minQ2=1/DIS_NC_10x100_minQ2=1.csv",
    "DIS/NC/18x275/minQ2=1/DIS_NC_18x275_minQ2=1.csv",
    "DIS/NC/10x275/minQ2=1/DIS_NC_10x275_minQ2=1.csv",
    "DIS/NC/5x41/minQ2=1/DIS_NC_5x41_minQ2=1.csv",
    "DIS/NC/5x100/minQ2=1/DIS_NC_5x100_minQ2=1.csv"
]
submitted = True # Set to False to actually print the commands

for dis_nc_file in dis_nc_minQ2_list:
  match = re.search(r'(\d+)x(\d+)', dis_nc_file)
  ebeam = match.group(1)
  pbeam = match.group(2)
  if not submitted:
    print("EBEAM="+ebeam+" PBEAM="+pbeam+" DETECTOR_VERSION="+detector_version+" DETECTOR_CONFIG="+detector_config+" JUG_XL_TAG="+jug_xl_tag+" COPYRECO="+copy_reco+" COPYFULL="+copy_full+" COPYLOG="+copy_log+" USERUCIO=true X509_USER_PROXY=secrets/x509_user_proxy scripts/submit_csv.sh osg_csv hepmc3 "+dis_nc_file+" 2")

# %%
import re

dis_nc_minQ2_10_list = [
    "DIS/NC/10x100/minQ2=10/DIS_NC_10x100_minQ2=10.csv",
    "DIS/NC/18x275/minQ2=10/DIS_NC_18x275_minQ2=10.csv",
    "DIS/NC/10x275/minQ2=10/DIS_NC_10x275_minQ2=10.csv",
    "DIS/NC/5x41/minQ2=10/DIS_NC_5x41_minQ2=10.csv",
    "DIS/NC/5x100/minQ2=10/DIS_NC_5x100_minQ2=10.csv"
]
submitted = True # Set to False to actually print the commands

for dis_nc_file in dis_nc_minQ2_10_list:
  match = re.search(r'(\d+)x(\d+)', dis_nc_file)
  ebeam = match.group(1)
  pbeam = match.group(2)
  if not submitted:
    print("EBEAM="+ebeam+" PBEAM="+pbeam+" DETECTOR_VERSION="+detector_version+" DETECTOR_CONFIG="+detector_config+" JUG_XL_TAG="+jug_xl_tag+" COPYRECO="+copy_reco+" COPYFULL="+copy_full+" COPYLOG="+copy_log+" USERUCIO=true X509_USER_PROXY=secrets/x509_user_proxy scripts/submit_csv.sh osg_csv hepmc3 "+dis_nc_file+" 2")

# %%
import re

dis_nc_minQ2_100_list = [
    "DIS/NC/10x100/minQ2=100/DIS_NC_10x100_minQ2=100.csv",
    "DIS/NC/18x275/minQ2=100/DIS_NC_18x275_minQ2=100.csv",
    "DIS/NC/10x275/minQ2=100/DIS_NC_10x275_minQ2=100.csv",
    "DIS/NC/5x41/minQ2=100/DIS_NC_5x41_minQ2=100.csv",
    "DIS/NC/5x100/minQ2=100/DIS_NC_5x100_minQ2=100.csv"
]
submitted = True # Set to False to actually print the commands

for dis_nc_file in dis_nc_minQ2_100_list:
  match = re.search(r'(\d+)x(\d+)', dis_nc_file)
  ebeam = match.group(1)
  pbeam = match.group(2)
  if not submitted:
    print("EBEAM="+ebeam+" PBEAM="+pbeam+" DETECTOR_VERSION="+detector_version+" DETECTOR_CONFIG="+detector_config+" JUG_XL_TAG="+jug_xl_tag+" COPYRECO="+copy_reco+" COPYFULL="+copy_full+" COPYLOG="+copy_log+" USERUCIO=true X509_USER_PROXY=secrets/x509_user_proxy scripts/submit_csv.sh osg_csv hepmc3 "+dis_nc_file+" 2")

# %%
import re

dis_nc_minQ2_1000_list = [
    "DIS/NC/10x100/minQ2=1000/DIS_NC_10x100_minQ2=1000.csv",
    "DIS/NC/18x275/minQ2=1000/DIS_NC_18x275_minQ2=1000.csv",
    "DIS/NC/10x275/minQ2=1000/DIS_NC_10x275_minQ2=1000.csv",
    "DIS/NC/5x100/minQ2=1000/DIS_NC_5x100_minQ2=1000.csv"
]
submitted = True # Set to False to actually print the commands

for dis_nc_file in dis_nc_minQ2_1000_list:
  match = re.search(r'(\d+)x(\d+)', dis_nc_file)
  ebeam = match.group(1)
  pbeam = match.group(2)
  if not submitted:
    print("EBEAM="+ebeam+" PBEAM="+pbeam+" DETECTOR_VERSION="+detector_version+" DETECTOR_CONFIG="+detector_config+" JUG_XL_TAG="+jug_xl_tag+" COPYRECO="+copy_reco+" COPYFULL="+copy_full+" COPYLOG="+copy_log+" USERUCIO=true X509_USER_PROXY=secrets/x509_user_proxy scripts/submit_csv.sh osg_csv hepmc3 "+dis_nc_file+" 2")

# %%
import re

dis_cc_minQ2_1000_list = [
    "DIS/CC/10x100/minQ2=1000/DIS_CC_10x100_minQ2=1000.csv",
    "DIS/CC/18x275/minQ2=1000/DIS_CC_18x275_minQ2=1000.csv",
    "DIS/CC/10x275/minQ2=1000/DIS_CC_10x275_minQ2=1000.csv",
    "DIS/CC/5x100/minQ2=1000/DIS_CC_5x100_minQ2=1000.csv"
]
submitted = True # Set to False to actually print the commands

for dis_cc_file in dis_cc_minQ2_1000_list:
  match = re.search(r'(\d+)x(\d+)', dis_cc_file)
  ebeam = match.group(1)
  pbeam = match.group(2)
  if not submitted:
    print("EBEAM="+ebeam+" PBEAM="+pbeam+" DETECTOR_VERSION="+detector_version+" DETECTOR_CONFIG="+detector_config+" JUG_XL_TAG="+jug_xl_tag+" COPYRECO="+copy_reco+" COPYFULL="+copy_full+" COPYLOG="+copy_log+" USERUCIO=true X509_USER_PROXY=secrets/x509_user_proxy scripts/submit_csv.sh osg_csv hepmc3 "+dis_cc_file+" 2")

# %%
import re

dis_cc_minQ2_100_list = [
    "DIS/CC/10x100/minQ2=100/DIS_CC_10x100_minQ2=100.csv",
    "DIS/CC/18x275/minQ2=100/DIS_CC_18x275_minQ2=100.csv",
    "DIS/CC/10x275/minQ2=100/DIS_CC_10x275_minQ2=100.csv",
    "DIS/CC/5x41/minQ2=100/DIS_CC_5x41_minQ2=100.csv",
    "DIS/CC/5x100/minQ2=100/DIS_CC_5x100_minQ2=100.csv"
]
submitted = True # Set to False to actually print the commands

for dis_cc_file in dis_cc_minQ2_100_list:
  match = re.search(r'(\d+)x(\d+)', dis_cc_file)
  ebeam = match.group(1)
  pbeam = match.group(2)
  if not submitted:
    print("EBEAM="+ebeam+" PBEAM="+pbeam+" DETECTOR_VERSION="+detector_version+" DETECTOR_CONFIG="+detector_config+" JUG_XL_TAG="+jug_xl_tag+" COPYRECO="+copy_reco+" COPYFULL="+copy_full+" COPYLOG="+copy_log+" USERUCIO=true X509_USER_PROXY=secrets/x509_user_proxy scripts/submit_csv.sh osg_csv hepmc3 "+dis_cc_file+" 2")

# %% [markdown]
# # **Decommissioned Datasets**

# %%
tcs_list = ["EXCLUSIVE/TCS/TCS_5x41_hiAcc.csv","EXCLUSIVE/TCS/TCS_5x41_hiDiv.csv","EXCLUSIVE/TCS/TCS_10x100_hiAcc.csv","EXCLUSIVE/TCS/TCS_10x100_hiDiv.csv", "EXCLUSIVE/TCS/TCS_18x275_hiAcc.csv", "EXCLUSIVE/TCS/TCS_18x275_hiDiv.csv"]
submitted = False

for tcs in tcs_list:
  match = re.search(r'(\d+)x(\d+)', tcs)
  ebeam = match.group(1)
  pbeam = match.group(2)
  if not submitted:
   print("EBEAM="+ebeam+" PBEAM="+pbeam+" DETECTOR_VERSION="+detector_version+" DETECTOR_CONFIG="+detector_config+" JUG_XL_TAG="+jug_xl_tag+" COPYRECO="+copy_reco+" COPYFULL="+copy_full+" COPYLOG="+copy_log+" USERUCIO=true X509_USER_PROXY=secrets/x509_user_proxy scripts/submit_csv.sh osg_csv hepmc3 "+tcs+" 2")
# Out:
# EBEAM=5 PBEAM=41 DETECTOR_VERSION=25.12.0 DETECTOR_CONFIG=epic_craterlake JUG_XL_TAG=25.12.0-stable COPYRECO=true COPYFULL=false COPYLOG=true USERUCIO=true X509_USER_PROXY=secrets/x509_user_proxy scripts/submit_csv.sh osg_csv hepmc3 EXCLUSIVE/TCS/TCS_5x41_hiAcc.csv 2
# EBEAM=5 PBEAM=41 DETECTOR_VERSION=25.12.0 DETECTOR_CONFIG=epic_craterlake JUG_XL_TAG=25.12.0-stable COPYRECO=true COPYFULL=false COPYLOG=true USERUCIO=true X509_USER_PROXY=secrets/x509_user_proxy scripts/submit_csv.sh osg_csv hepmc3 EXCLUSIVE/TCS/TCS_5x41_hiDiv.csv 2
# EBEAM=10 PBEAM=100 DETECTOR_VERSION=25.12.0 DETECTOR_CONFIG=epic_craterlake JUG_XL_TAG=25.12.0-stable COPYRECO=true COPYFULL=false COPYLOG=true USERUCIO=true X509_USER_PROXY=secrets/x509_user_proxy scripts/submit_csv.sh osg_csv hepmc3 EXCLUSIVE/TCS/TCS_10x100_hiAcc.csv 2
# ...

# %%
dvcs_list = ["EXCLUSIVE/DVCS/DVCS_5x41_hiAcc.csv","EXCLUSIVE/DVCS/DVCS_5x41_hiDiv.csv","EXCLUSIVE/DVCS/DVCS_10x100_hiAcc.csv","EXCLUSIVE/DVCS/DVCS_10x100_hiDiv.csv", "EXCLUSIVE/DVCS/DVCS_18x275_hiAcc.csv", "EXCLUSIVE/DVCS/DVCS_18x275_hiDiv.csv"]
submitted = False

for dvcs in dvcs_list:
  match = re.search(r'(\d+)x(\d+)', dvcs)
  ebeam = match.group(1)
  pbeam = match.group(2)
  if not submitted:
    print("EBEAM="+ebeam+" PBEAM="+pbeam+" DETECTOR_VERSION="+detector_version+" DETECTOR_CONFIG="+detector_config+" JUG_XL_TAG="+jug_xl_tag+" COPYRECO="+copy_reco+" COPYFULL="+copy_full+" COPYLOG="+copy_log+" USERUCIO=true X509_USER_PROXY=secrets/x509_user_proxy scripts/submit_csv.sh osg_csv hepmc3 "+dvcs+" 2")

# %%
demp_list = ["EXCLUSIVE/DEMP/DEMPgen-1.2.2_10x100_pi+.csv","EXCLUSIVE/DEMP/DEMPgen-1.2.2_18x275_pi+.csv", "EXCLUSIVE/DEMP/DEMPgen-1.2.2_5x41_K+Lambda.csv", "EXCLUSIVE/DEMP/DEMPgen-1.2.2_5x41_pi+.csv", "EXCLUSIVE/DEMP/DEMPgen-1.2.3_10x130_K+Lambda.csv", "EXCLUSIVE/DEMP/DEMPgen-1.2.3_10x130_pi+.csv"]
submitted = False

for demp in demp_list:
  match = re.search(r'(\d+)x(\d+)', demp)
  ebeam = match.group(1)
  pbeam = match.group(2)
  if not submitted:
    print("EBEAM="+ebeam+" PBEAM="+pbeam+" DETECTOR_VERSION="+detector_version+" DETECTOR_CONFIG="+detector_config+" JUG_XL_TAG="+jug_xl_tag+" COPYRECO="+copy_reco+" COPYFULL="+copy_full+" COPYLOG="+copy_log+" USERUCIO=true X509_USER_PROXY=secrets/x509_user_proxy scripts/submit_csv.sh osg_csv hepmc3 "+demp+" 2")

# %%
dvmp_list = ["EXCLUSIVE/DVMP/EpIC1.0.0-1.1_DVMP_10x100_hiAcc_ab.csv"]
submitted = False

for dvmp in dvmp_list:
  match = re.search(r'(\d+)x(\d+)', dvmp)
  ebeam = match.group(1)
  pbeam = match.group(2)
  if not submitted:
    print("EBEAM="+ebeam+" PBEAM="+pbeam+" DETECTOR_VERSION="+detector_version+" DETECTOR_CONFIG="+detector_config+" JUG_XL_TAG="+jug_xl_tag+" COPYRECO="+copy_reco+" COPYFULL="+copy_full+" COPYLOG="+copy_log+" USERUCIO=true X509_USER_PROXY=secrets/x509_user_proxy scripts/submit_csv.sh osg_csv hepmc3 "+dvmp+" 2")

# %%
diffractive_phi_list = ["EXCLUSIVE/DIFFRACTIVE_PHI/sartre1.39-1.0_coherent_phi_eAu_bsat_10x100.csv"]
submitted = False

for diffractive_phi in diffractive_phi_list:
  ebeam = "10"
  pbeam = "100_Au197"
  if not submitted:
    print("EBEAM="+ebeam+" PBEAM="+pbeam+" DETECTOR_VERSION="+detector_version+" DETECTOR_CONFIG="+detector_config+" JUG_XL_TAG="+jug_xl_tag+" COPYRECO="+copy_reco+" COPYFULL="+copy_full+" COPYLOG="+copy_log+" USERUCIO=true X509_USER_PROXY=secrets/x509_user_proxy scripts/submit_csv.sh osg_csv hepmc3 "+diffractive_phi+" 2")
# Out:
# EBEAM=10 PBEAM=100_Au197 DETECTOR_VERSION=26.02.0 DETECTOR_CONFIG=epic_craterlake JUG_XL_TAG=26.02.0-stable COPYRECO=true COPYFULL=false COPYLOG=true USERUCIO=true X509_USER_PROXY=secrets/x509_user_proxy scripts/submit_csv.sh osg_csv hepmc3 EXCLUSIVE/DIFFRACTIVE_PHI/sartre1.39-1.0_coherent_phi_eAu_bsat_10x100.csv 2

# %%
eA_list = ["DIS/eA/BeAGLE1.03.02-1.2_DIS_eHe3_10x166_q2_2to10.csv", "DIS/eA/BeAGLE1.03.02-1.2_DIS_eHe3_10x166_q2_10to100.csv", "DIS/eA/BeAGLE1.03.02-1.2_DIS_eHe3_10x166_q2_100to10000.csv"]
pbeam_list=["166_He3", "166_He3", "166_He3"]
submitted = False

for eA, pbeam in zip(eA_list, pbeam_list):
  match = re.search(r'(\d+)x(\d+)', eA)
  ebeam = match.group(1)
  if not submitted:
    print("EBEAM="+ebeam+" PBEAM="+pbeam+" DETECTOR_VERSION="+detector_version+" DETECTOR_CONFIG="+detector_config+" JUG_XL_TAG="+jug_xl_tag+" COPYRECO="+copy_reco+" COPYFULL="+copy_full+" COPYLOG="+copy_log+" USERUCIO=true X509_USER_PROXY=secrets/x509_user_proxy scripts/submit_csv.sh osg_csv hepmc3 "+eA+" 2")
